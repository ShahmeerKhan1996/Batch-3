# %%
import pandas as pd
import numpy as np
import seaborn as sns                        #visualisation
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cars.csv")
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# #### Check and Drop Duplicate Records

# %%
df[df.duplicated()]
# Out:
#          Make     Model  Year             Engine Fuel Type  Engine HP  \
# 14        BMW  1 Series  2013  premium unleaded (required)      230.0
# 18       Audi       100  1992             regular unleaded      172.0
# 20       Audi       100  1992             regular unleaded      172.0
# 24       Audi       100  1993             regular unleaded      172.0
# 25       Audi       100  1993             regular unleaded      172.0
# ...       ...       ...   ...                          ...        ...
# 11481  Suzuki      X-90  1998             regular unleaded       95.0
# 11603   Volvo      XC60  2017             regular unleaded      302.0
# 11604   Volvo      XC60  2017             regular unleaded      240.0
# 11708  Suzuki       XL7  2008             regular unleaded      252.0
# 11717  Suzuki       XL7  2008             regular unleaded      252.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# #### Check and Drop missing or null values

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3376
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# Average MPG             0
# dtype: int64

# %%
df = df.dropna()

# %%
df.count()
# Out:
# Make                 7735
# Model                7735
# Year                 7735
# Engine Fuel Type     7735
# Engine HP            7735
# Engine Cylinders     7735
# Transmission Type    7735
# Driven_Wheels        7735
# Number of Doors      7735
# Market Category      7735
# Vehicle Size         7735
# Vehicle Style        7735
# highway MPG          7735
# city mpg             7735
# Popularity           7735
# MSRP                 7735
# Average MPG          7735
# dtype: int64

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# #### What are the top 10 average MSRP (Price) per car brand (rounded figure)? with Horizontal Bar Plot

# %%
avg_msrp_by_make = df.groupby('Make')['MSRP'].mean().nlargest(10).round(0).sort_values(ascending=False)
avg_msrp_by_make
# Out:
# Make
# Bugatti         1757224.0
# Maybach          546222.0
# Rolls-Royce      351131.0
# Lamborghini      331567.0
# Bentley          247169.0
# McLaren          239805.0
# Ferrari          238219.0
# Spyker           213323.0
# Aston Martin     197910.0
# Maserati         114208.0
# Name: MSRP, dtype: float64

# %%
avg_msrp_by_make.nlargest(10).plot(kind='barh', figsize=(10, 6), color='skyblue')
plt.title('Top 15 Car Brands by Average MSRP')
plt.xlabel('Average MSRP ($)')
plt.ylabel('Car Brand (Make)')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### How has the MSRP (price) changed over the years (rounded figure)? with Line Plot

# %%
avg_msrp_by_year = df.groupby('Year')['MSRP'].mean().round(0)

print(avg_msrp_by_year)
# Out:
# Year
# 1990     2020.0
# 1991     2081.0
# 1992     2078.0
# 1993     2187.0
# 1994     2312.0
# 1995     2607.0
# 1996     2497.0
# 1997     3105.0
# 1998     2976.0
# 1999     3096.0
# 2000     3167.0
# 2001    41501.0
# 2002    33744.0
# 2003    39774.0
# 2004    36107.0
# 2005    36747.0
# 2006    32056.0
# 2007    34974.0
# 2008    54139.0
# 2009    49839.0
# 2010    50642.0
# 2011    57548.0
# 2012    59516.0
# 2013    48699.0
# 2014    63226.0
# 2015    46794.0
# 2016    47221.0
# 2017    42192.0
# Name: MSRP, dtype: float64

# %%
plt.figure(figsize=(10, 5))
avg_msrp_by_year.plot(kind='line', marker='o', color='teal')

plt.title('Average MSRP Over the Years')
plt.xlabel('Year')
plt.ylabel('Average MSRP ($)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### How Engine HP (power) and MPG (efficiency) have changed over the years? show with two line plots
#
# Hint: Average of (city mpg + highway MPG)

# %%
df['Average MPG'] = (df['city mpg'] + df['highway MPG']) / 2
yearly_stats = df.groupby('Year')[['Engine HP', 'Average MPG']].mean().round(1)
yearly_stats
# Out:
#       Engine HP  Average MPG
# Year
# 1990      141.1         20.1
# 1991      147.8         19.2
# 1992      151.4         21.0
# 1993      155.6         21.1
# 1994      157.2         20.8
# 1995      174.7         20.1
# 1996      173.6         20.6
# 1997      184.9         19.4
# 1998      190.1         19.0
# 1999      188.7         19.9
# 2000      183.5         20.9
# 2001      194.1         20.7
# 2002      195.8         19.8
# 2003      206.1         19.7
# 2004      214.9         19.9
# 2005      218.5         20.3
# 2006      229.8         20.2
# 2007      251.8         18.9
# 2008      255.8         19.8
# 2009      251.7         20.6
# 2010      249.4         20.9
# 2011      262.8         21.9
# 2012      265.6         23.0
# 2013      267.1         24.2
# 2014      291.8         24.8
# 2015      271.0         25.2
# 2016      273.8         25.5
# 2017      274.6         25.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(yearly_stats.index, yearly_stats['Engine HP'], label='Average Horsepower', color='firebrick', marker='o')
plt.plot(yearly_stats.index, yearly_stats['Average MPG'], label='Average MPG', color='seagreen', marker='o')

plt.title('Average Horsepower and MPG Over the Years')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### What percentage of cars are Compact, Midsize, or Large? Show with Pie chart

# %%
df.loc[:, 'Vehicle Size'] = df['Vehicle Size'].astype(str)
vehicle_size_counts = df_clean['Vehicle Size'].value_counts()
vehicle_size_counts
# Out:
# Vehicle Size
# Midsize    3043
# Compact    2847
# Large      1845
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7, 7))
vehicle_size_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral', 'lightgreen'])
plt.title('Vehicle Size Distribution')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Which vehicle styles are sold the most? show with vertical bar plot

# %%
vehicle_style_counts = df['Vehicle Style'].value_counts()

print("Most Sold Vehicle Styles:")
print(vehicle_style_counts)
# Out:
# Most Sold Vehicle Styles:
# Vehicle Style
# 4dr SUV                2053
# Sedan                  1801
# Coupe                   922
# Convertible             645
# 4dr Hatchback           639
# 2dr Hatchback           409
# Wagon                   349
# Crew Cab Pickup         334
# Extended Cab Pickup     187
# Regular Cab Pickup      176
# Passenger Van           100
# Passenger Minivan        61
# Cargo Van                34
# 2dr SUV                  14
# Convertible SUV           6
# Cargo Minivan             5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
vehicle_style_counts.plot(
    kind='bar',
    color='green'
)

plt.title('Top 10 Most Sold Vehicle Styles')
plt.xlabel('Vehicle Style')
plt.ylabel('Number of Vehicles Sold')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Which car brands have the most vehicles priced at $40,000 or more and with a popularity score of at least 1000?

# %%
result = df[(df['Popularity'] >= 1000) & (df['MSRP'] >= 40000)]
grouped = result.groupby('Make').size().sort_values(ascending=False)

print(grouped)
# Out:
# Make
# Cadillac       354
# BMW            269
# Audi           224
# Chevrolet      171
# Porsche        123
# Ford           105
# Nissan          69
# Ferrari         68
# Lamborghini     52
# Toyota          50
# Dodge           49
# Kia             16
# Hyundai         13
# Chrysler        12
# Honda            8
# dtype: int64
